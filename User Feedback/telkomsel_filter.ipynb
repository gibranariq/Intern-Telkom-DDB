# %%
import pandas as pd

# %%
# df = pd.read_excel('Google Play.xlsx')

df = pd.read_excel('Appstore.xlsx')

# %%
df
# Out:
#                                                 review  \
# 0    Gakjelas banget anjg gabguan 1 minggu udh 2x +...
# 1                            Sering gangguan dan lelet
# 2                       Belakangan ini sering gangguan
# 3    Aplikasi SAMPAH. Selalu minta muat ulang untuk...
# 4    Fitur pengaduan gk jelas, masak mau pengaduan ...
# ..                                                 ...
# 179                             MYTELKOMSEL LANCIAOOOO
# 180  APLIKASI ANEH, UDH UBAH KE NOMOR YANG BARU DAN...
# 181  Ini app nyuruh buka my Telkomsel, tapi di my T...
# 182  T O L O L gak bisa pindah dari aplikasi myindi...
# 183  Very bad the way your guys merge the app with ...
#
#                          Kategori
# 0               Kualitas Internet
# 1               Kualitas Internet
# 2               Kualitas Internet
# 3    Usability & Reliability Apps
# 4    Usability & Reliability Apps
# ..                            ...
# 179                  Unidentified
# ...

# %%
# Define the keywords to filter the reviews
keywords = ['telkomsel', 'mytelkomsel', 'tsel', 'mytsel', 'my telkomsel', 'telkmsel', 'telkomsel']

# Filter the rows that contain any of the keywords (case insensitive)
# df_new = df[df['content'].str.contains('|'.join(keywords), case=False, na=False)] #if using Google Play
df_new = df[df['review'].str.contains('|'.join(keywords), case=False, na=False)] #if using Appstore

# Display the filtered DataFrame to the user
# import ace_tools_open as tools; tools.display_dataframe_to_user(name="Filtered GooglePlay Reviews", dataframe=df_new) #if using Google Play
import ace_tools_open as tools; tools.display_dataframe_to_user(name="Filtered Appstore Reviews", dataframe=df_new) #if using Appstore
# Out:
# Filtered Appstore Reviews
# <table id="itables_9a3b941c_77de_4401_8d8c_767c6dbaaea3" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>review</th>
#       <th>Kategori</th>
#     </tr>
#   </thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <div style="float:left; margin-right: 10px;">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
# ...

# %%
# df_new.to_excel('Filtered Google Play Reviews.xlsx', index=False) #if using Google Play
df_new.to_excel('Filtered Appstore Reviews.xlsx', index=False) #if using Appstore
